# %%
import pyLDAvis
import pyLDAvis.gensim 
import matplotlib.pyplot as plt
import pickle

# %%
f = open("pyldavis_graph.pkl","rb")
vis = pickle.load(f)
f.close()

# %%
pyLDAvis.enable_notebook()
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 4     -0.141008  0.142683       1        1  10.315442
# 0     -0.100556 -0.108379       2        1   9.746138
# 11    -0.090844  0.118165       3        1   9.428145
# 7      0.102724 -0.154282       4        1   8.520016
# 3      0.022292  0.080891       5        1   8.209249
# 9      0.015479  0.034719       6        1   8.119633
# 5     -0.038970 -0.086740       7        1   8.038317
# 2     -0.146737 -0.143885       8        1   7.969481
# 8      0.160747  0.097560       9        1   7.934728
# 6     -0.049893  0.050658      10        1   7.432810
# 10     0.132689 -0.017086      11        1   7.429176
# 1      0.134075 -0.014304      12        1   6.856860, topic_info=    Category         Freq     Term        Total  loglift  logprob
# 24   Default  2046.000000   avamar  2046.000000  30.0000  30.0000
# 92   Default  2604.000000     file  2604.000000  29.0000  29.0000
# ...

# %%
pyLDAvis.save_html(vis, "LDA_keywords.html")
